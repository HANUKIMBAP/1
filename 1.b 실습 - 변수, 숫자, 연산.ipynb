# %% [markdown]
# # <font color='red'> 실습 </font>

# %% [markdown]
# #  <font color='blue'>1. 다음을 실행하면 어떤 결과가 나올까요?  </font>

# %%
x = 10
x = 20
x = 15
x

# %%
type(x)

# %%
z = x/y
z

# %%
type(z)

# %% [markdown]
# #  <font color='blue'>2. 넓이와 둘레길이를 구하는 코드를 만드세요. a는 11, b는 7일때의 넓이와 둘레의 길이를 구하세요. </font>
# ![image.png](attachment:image.png)

# %%
a=11
b=7

area=a*b
perimeter=2*(a+b)
print(area)
print(perimeter)
# Out:
# 77
# 36

# %% [markdown]
# #  <font color='blue'> 3. 다음 코드를 실행하여 결과를 확인하세요. </font>

# %%
x = 25
y = 20
z = 3
f = 2

# %%
ans = (x - y) * z / f       
ans

# %%
e = ((x - y) * z) / f    
e

# %%
z = (x - y) * (z / f);    
z

# %% [markdown]
# # <font color='blue'> 4. 어떤 숫자 x가 주어졌을때, 그 숫자가 짝수인지 홀수인지 계산하는 코드를 작성하세요.  </font>

# %%
x=int(input('어떤 숫자:'))

if x%2==0:
    print('짝수')
else:
    print('홀수')
# Out:
# 어떤 숫자:2
# 짝수

# %%
a=20
area=6*a**2
volume=a**3

print(area)
print(volume)
# Out:
# 2400
# 8000

# %% [markdown]
# #  <font color='blue'>6.     x 가 4, y 가 2일때 다음 식을 만족하는 z를 구하는 코드를 짜세요. </font>
# z = |x − y| *  (x + y)

# %%
x=4
y=2

z=abs(x-y)*(x+y)
print(z)
# Out:
# 12

# %% [markdown]
# # <font color='blue'> 7. 현재 속도가 90 KM/H 다. 이를 MP/H(Miles per hour) 로 계산하는 코드를 작성하세요.  </font>
# ![image.png](attachment:image.png)
# MPH = 0.6214 * KMH

# %%
a=90
mph=0.6214*a

mph
# Out:
# 55.925999999999995
